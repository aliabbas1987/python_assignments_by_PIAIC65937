# %%
student_name = "i am student of AI Batch 3"
student_name = student_name.capitalize() #function 1) Capitalize 
print(student_name) #Print output

student_name = student_name.casefold() # function 2) Casefold
print(student_name)

result_string = student_name.center(5,'*') # function 3) center
print(result_string)

listCount = [1, 1, 1, 2, 3, 2, 1] # function 4) count
print(listCount.count(1))

print(student_name.encode('ascii')) #econde string
print(student_name.endswith('3')) #end with a particualr string

student_name = "i\tam\tstudent\tof\tAI\tBatch\t3"
print(student_name.expandtabs()) #expand string and also apply tab
print(student_name.find('of')) #find the place of sub string

student_name = "i am student of AI Batch 3 {}"
print(student_name.format('Morning')) #format student

dict_d = {'name':'Ali Abbas', 'Roll_no':'786'} 
  
print("{name}'s roll number is {Roll_no}".format_map(dict_d)) #format map 

listAnimal = ['cat', 'bat', 'mat', 'cat', 'pet']
print(listAnimal.index('mat')); #index 

print(student_name.isalnum()) #check if a string have numeric or not

print(student_name.isalpha()) #check if string have alpha numeric or not
print(student_name.isascii()) #check if ascii or not
print(student_name.isdecimal()) #check if string contian decimal
print(student_name.isdigit())#Returns True if all characters in the string are digits
print(student_name.isidentifier()) #Returns True if the string is an identifier
print(student_name.islower()) #Returns True if all characters in the string are lower case


print(student_name.isprintable()) #returns True if all characters in the string are printable
print(student_name.isspace()) #Returns True if all characters in the string are whitespaces
print(student_name.istitle()) #Returns True if the string follows the rules of a title
print(student_name.isupper()) #Returns True if all characters in the string are upper case
print("#".join(student_name)) #Joins the elements of an iterable to the end of the string

print(student_name.lower()) #Converts a string into lower case
print(student_name.lstrip()) #Returns a left trim version of the string

print(student_name.partition("student")) #Returns a tuple where the string is parted into three parts
print(student_name.replace("i am","I'm")) #Returns a string where a specified value is replaced with a specified value
print(student_name.rfind("student")) #Searches the string for a specified value and returns the last position of where it was found
print(student_name.rindex("student")) #Searches the string for a specified value and returns the last position of where it was found
print(student_name.rjust(5)) #Returns a right justified version of the string
print(student_name.rpartition("student")) #Returns a tuple where the string is parted into three parts
print(student_name.rsplit("student"))#Splits the string at the specified separator, and returns a list
print(student_name.rstrip()) #Returns a right trim version of the string
print(student_name.split()) #Splits the string at the specified separator, and returns a list
print(student_name.splitlines()) #Splits the string at line breaks and returns a list
print(student_name.startswith("student")) #Returns true if the string starts with the specified value
print(student_name.strip()) #Returns a trimmed version of the string
print(student_name.swapcase()) #Swaps cases, lower case becomes upper case and vice versa
print(student_name.zfill(10)) #Fills the string with a specified number of 0 values at the beginning
# Out:
# I am student of ai batch 3
# i am student of ai batch 3
# i am student of ai batch 3
# 4
# b'i am student of ai batch 3'
# True
# i       am      student of      AI      Batch   3
# 13
# i am student of AI Batch 3 Morning
# Ali Abbas's roll number is 786
# 2
# False
# False
# True
# False
# False
# False
# False
# True
# False
# False
# False
# i# #a#m# #s#t#u#d#e#n#t# #o#f# #A#I# #B#a#t#c#h# #3# #{#}
# i am student of ai batch 3 {}
# i am student of AI Batch 3 {}
# ('i am ', 'student', ' of AI Batch 3 {}')
# I'm student of AI Batch 3 {}
# 5
# 5
# i am student of AI Batch 3 {}
# ('i am ', 'student', ' of AI Batch 3 {}')
# ['i am ', ' of AI Batch 3 {}']
# i am student of AI Batch 3 {}
# ['i', 'am', 'student', 'of', 'AI', 'Batch', '3', '{}']
# ['i am student of AI Batch 3 {}']
# False
# i am student of AI Batch 3 {}
# I AM STUDENT OF ai bATCH 3 {}
# i am student of AI Batch 3 {}
